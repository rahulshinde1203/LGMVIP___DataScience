# %% [markdown]
# <a href="https://colab.research.google.com/github/rahulshinde1203/LGMVIP___DataScience/blob/main/Image_to_pencil_sketch_using__python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Performed by : Rahul Shinde

# %% [markdown]
# LGVIP-DataScience Task 1

# %% [markdown]
# Image to Pencil Sketch with Python

# %% [markdown]
# Import the Libraries

# %%
from google.colab.patches import cv2_imshow

# %%
import cv2

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# Loading the Original Image

# %%
image = cv2.imread("tomandjerry.jpg")

# %%
image = cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
plt.figure(figsize=(8,8))
plt.imshow(image)
plt.axis("off")
plt.title("Original Image")
plt.show()

# %% [markdown]
# Converting Image to Gray Scale

# %%
img_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# %%
plt.figure(figsize=(8,8))
plt.imshow(img_gray,cmap="gray")
plt.axis("off")
plt.title("GrayScale Image")
plt.show()

# %% [markdown]
# Inverting the Gray Image

# %%
image_invert = cv2.bitwise_not(img_gray)

# %%
plt.figure(figsize=(8,8))
plt.imshow(image_invert,cmap="gray")
plt.axis("off")
plt.title("Inverted Image")
plt.show()

# %% [markdown]
# Blur the image

# %%
blur_image=cv2.GaussianBlur(image_invert,(21,21),sigmaX=0, sigmaY=0)

# %%
plt.figure(figsize=(8,8))
plt.imshow(blur_image,cmap="gray")
plt.axis("off")
plt.title("Blurry Image")
plt.show()

# %% [markdown]
# Final Pencil Sketch : The Required output

# %%
sketch = cv2.divide(img_gray, 255 - blur_image, scale=255)

# %%
plt.figure(figsize=(8,8))
plt.imshow(sketch,cmap="gray")
plt.axis("off")
plt.title("Final Sketch")
plt.show()
